# %% [markdown]
# <a href="https://colab.research.google.com/github/seenu-g/school_of_ai/blob/master/chap14/Overlap_and_mask_Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys
import os
folder = '/content/gdrive/My Drive/school_of_ai/chap14/'
os.chdir(folder)
print(os.getcwd()) 
for items in os.listdir(folder):
   print(items)
sys.path.append(folder)
# Out:
# /content/gdrive/My Drive/school_of_ai/chap14
# Detectron2 Tutorial.ipynb
# collect_data
# images
# Background
# Foreground
# Mask
# Fg-Bg-Mask
# Fg-Bg
# Overlap_and_mask.ipynb

# %%
ls '/content/gdrive/My Drive/school_of_ai/chap14/'
# Out:
#  Background/                  Fg-Bg/        images/
#  collect_data/                Fg-Bg-Mask/   Mask/
# 'Detectron2 Tutorial.ipynb'   Foreground/   Overlap_and_mask.ipynb

# %%
import numpy as np
from PIL import Image
import random
import copy
import PIL

# %%
start = 240001 # -----------------------You should choose your numbers----------------------------------
black = np.zeros((224,224,3))

for i in range(1,100): #1 background image  -------------This is 1-100 == Same for all -------------

    bg = Image.open(f'{folder}Background/bg{str(i)}.jpg')

    for j in  range(61,81): #1 foreground image  ---------------You should choose your numbers. Place only 20 images no flipped one-------
     
      fg = Image.open(f'{folder}Foreground/fg{str(j)}.png')
      mask = Image.open(f'{folder}Mask/mask{str(j)}.png')

      for k in range(1,21): #---------------------Randomly Placing 20 times(Same for all)--------------------------------
       
        r1 = random.randint(1, 80)
        r2 = random.randint(1, 80)
        bg1 = copy.deepcopy(bg)
        bg2 = copy.deepcopy(bg)
        fg1 = copy.deepcopy(fg)
        m1 = copy.deepcopy(mask)
        black_img1 = Image.fromarray(black,mode='RGB')
        black_img2 = Image.fromarray(black,mode='RGB')

        flipfg = fg1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip image
        flipmask = m1.transpose(PIL.Image.FLIP_LEFT_RIGHT) #flip mask

        
        fg1.putalpha(255)
        bg1.paste(fg1, (r1,r2),fg1)
        flipfg.putalpha(255)
        bg2.paste(flipfg,(r1,r2),flipfg)
        m1.putalpha(255)
        black_img1.paste(m1,(r1,r2), m1)
        flipmask.putalpha(255)
        black_img2.paste(flipmask,(r1,r2), flipmask)

        bg1.save(f"{folder}Fg-Bg/fg-bg{str(start)}.jpg")#------------Create Different folder-------------
        black_img1.save(f"{folder}Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg") #-------------Create Different Path folder----

        start+=1

        bg2.save(f"{folder}Fg-Bg/fg-bg{str(start)}.jpg")#------------Create Different folder---------------
        black_img2.save(f"{folder}Fg-Bg-Mask/fg-bg-mask{str(start)}.jpg")#------------Create Different folder-----------

        start+=1
        print(start)
# Out:
# Streaming output truncated to the last 5000 lines.
# 309205
# 309207
# 309209
# 309211
# 309213
# 309215
# 309217
# 309219
# 309221
# 309223
# 309225
# 309227
# 309229
# 309231
# 309233
# 309235
# 309237
# 309239
# 309241
# 309243
# 309245
# 309247
# 309249
# 309251
# 309253
# 309255
# 309257
# 309259
# 309261
# 309263
# 309265
# 309267
# 309269
# 309271
# 309273
# 309275
# 309277
# 309279
# 309281
# 309283
# 309285
# 309287
# 309289
# 309291
# 309293
# 309295
# 309297
# 309299
# 309301
# 309303
# 309305
# 309307
# 309309
# 309311
# 309313
# 309315
# 309317
# 309319
# 309321
# 309323
# 309325
# 309327
# 309329
# 309331
# 309333
# 309335
# 309337
# 309339
# 309341
# 309343
# 309345
# 309347
# 309349
# 309351
# 309353
# 309355
# 309357
# 309359
# 309361
# 309363
# 309365
# 309367
# 309369
# 309371
# 309373
# 309375
# 309377
# 309379
# 309381
# 309383
# 309385
# 309387
# 309389
# 309391
# 309393
# 309395
# 309397
# 309399
# 309401
# 309403
# 309405
# 309407
# 309409
# 309411
# 309413
# ...
