# %% [markdown]
# <a href="https://colab.research.google.com/github/seenu-g/school_of_ai/blob/master/chap14/create_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd /content/
# Out:
# /content

# %%
#To import zip file
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "/content/gdrive/My Drive/school_of_ai/chap14/data_Part3.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files from data_Part3.zip now...') 
    zip.extractall() 
    print('Done!') 
    zip.close()
# Out:
# Extracting all the files from data_Part3.zip now...
# Done!

# %%
from zipfile import ZipFile 
  
# specifying the zip file name 
file_name = "/content/gdrive/My Drive/school_of_ai/chap14/Depth_Part3.zip"
  
# opening the zip file in READ mode 
with ZipFile(file_name, 'r') as zip: 
    # printing all the contents of the zip file 
    #zip.printdir() 
  
    # extracting all the files 
    print('Extracting all the files from Depth_Part3.zip now...') 
    zip.extractall() 
    print('Done!') 
    zip.close()
# Out:
# Extracting all the files from Depth_Part3.zip now...
# Done!

# %%
ls Overlay3
# Out:
# Fg-Bg/  Fg-Bg-Mask/  mapping.txt

# %%
ls Overlay3/Fg-Bg | wc -l
# Out:
# 80000

# %%
ls Overlay3/Fg-Bg-Mask | wc -l
# Out:
# 80000

# %%
ls Depth_Part3 | wc -l
# Out:
# 80001

# %%
mv  Overlay3  data_3

# %%
mv Depth_Part3 data_3

# %%
mv data_3/Depth_Part3 data_3/Depth

# %%
ls data_3
# Out:
# Depth/  Fg-Bg/  Fg-Bg-Mask/  mapping.txt

# %%
ls data_3/Fg-Bg | wc -l
# Out:
# 80000

# %%
ls data_3/Fg-Bg-Mask | wc -l
# Out:
# 80000

# %%
ls data_3/Depth | wc -l
# Out:
# 80001

# %%
from zipfile import ZipFile 
import zipfile
import os 
  
def get_all_file_paths(directory): 
    outfile = open("/content/data_part_3_files.txt","a+")
    # initializing empty file paths list 
    file_paths = [] 
  
    # crawling through directory and subdirectories 
    for root, directories, files in os.walk(directory): 
        for filename in files: 
            # join the two strings in order to form the full filepath. 
            filepath = os.path.join(root, filename) 
            file_paths.append(filepath) 
            outfile.write(filepath+ '\n')
    outfile.close()
    # returning all file paths 
    return file_paths         

def main():
    # path to folder which needs to be zipped 
    directory = 'data_3'
  
    # calling function to get all file paths in the directory 
    file_paths = get_all_file_paths(directory) 
  
    # printing the list of all files to be zipped 
    print('Following files will be zipped:') 
    for file_name in file_paths: 
        print(file_name) 
  
    # writing files to a zipfile 
    with ZipFile('/content/gdrive/My Drive/school_of_ai/chap14/data_part3.zip','w', compression = zipfile.ZIP_DEFLATED) as zip: 
        # writing each file one by one 
        for file in file_paths: 
            zip.write(file) 
        zip.close()
  
    print('All files zipped successfully!') 

main()
# Out:
# Streaming output truncated to the last 5000 lines.
# data_3/Fg-Bg-Mask/fg-bg-mask301030.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask316720.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask277263.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask287695.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask283257.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask314891.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask282835.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask304558.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask309100.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask242244.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask289032.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask279558.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask264833.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask240972.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask299607.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask242803.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask309081.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask269273.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask305765.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask319342.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask289143.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask269664.jpg
# data_3/Fg-Bg-Mask/fg-bg-mask252257.jpg
# ...
